# %% [markdown]
# # Analysis of the relation between the sensation level difference (SL BC - SL AC) with signal at BCD side and the fitting appraisal

# %% [markdown]
# 1 July 2023 Guido Cattani

# %%
from pathlib import Path
import pandas as pd
from scipy.stats import mannwhitneyu as mannwhitneyu
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def read_AC_thresholds():
    # read measured thresholds
    f_in = '//media/guido/LACIE/Cingle_Guido/Master/Implant/Primary_data/AC_measured_thresholds.csv'
    p_in = Path(f_in)   
    df = pd.read_csv(p_in)
    df.set_index('Study_ID', inplace=True)
    return df

# %%
def present_AC_thresholds():
    ac = read_AC_thresholds()
    ac1 = ac[['AC_500', 'AC_1000', 
              'AC_2000', 'AC_4000']].copy()
    pta = ac1.iloc[:, 1:].mean(axis='columns').round(1)
    ac1.insert(4, column= 'PTA (0.5-4 kHz)', value=pta)
    pta_hf = ac1.iloc[:, 2:].mean(axis='columns').round(1)
    ac1.insert(5, column= 'PTA_HF (1-4 kHz)', value=pta_hf)
    return ac1

# %%
def read_BC_direct():
    f_in = '/media/guido/LACIE/Cingle_Guido/Master/Implant/Primary_data/BCdirect.csv'
    p_in = Path(f_in)   
    df = pd.read_csv(p_in)
    df = df.drop(['Unnamed: 0'], axis=1)
    df.set_index('Study_ID', inplace=True)
    return df

# %%
def present_BCdirect_thresholds():
    bc = read_BC_direct()
    bc1 = bc[['BCdimp_500', 'BCdimp_1000', 'BCdimp_2000', 'BCdimp_4000']].copy()
    pta = bc1.iloc[:, 1:].mean(axis='columns').round(1)
    bc1.insert(4, column= 'PTA (0.5-4 kHz)', value=pta)
    pta_hf = bc1.iloc[:, 2:].mean(axis='columns').round(1)
    bc1.insert(5, column= 'PTA_HF (1-4 kHz)', value=pta_hf)
    bc1.dropna(inplace=True)
    return bc1

# %%
# read difference sensation levels BC - AC simulated with a 65 dB ISDS input signal at BCD side (90 degree angle)
def read_diff_sl():
    f_in = '/media/guido/LACIE/Cingle_Guido/Master/Implant/Calculated_data/Diff_SL_65dB_S_BCDside.csv'
    p_in = Path(f_in)   
    df = pd.read_csv(p_in)
    df.set_index('Study_ID', drop=True, inplace=True, verify_integrity=True)
    return df

# %%
def read_SL_BC():
    # read sensation levels BC path in the condition with signal at BCD side
    f_in = '/media/guido/LACIE/Cingle_Guido/Master/Implant/Calculated_data/BC_SL_65dB_90deg.csv'
    p_in = Path(f_in)   
    df = pd.read_csv(p_in)
    df.set_index('Study_ID', drop=True, inplace=True, verify_integrity=True)
    return df

# %%
def diff_sl_filtered():
    # boolean mask func. for diff SL, CROS balance criterium
    diff_sl= read_diff_sl()
    diff_sl.dropna(inplace = True)
    criterium = -3
    pos_diff_sl = diff_sl >= criterium
    pos_diff_sl
    return pos_diff_sl

# %%
def sl_bc_filtered():
    # boolean mask func. for SL BC, audibility criterium of BC path
    sl_bc= read_SL_BC()
    sl_bc.dropna(inplace = True)
    criterium = 0
    pos_sl = sl_bc > criterium
    pos_sl
    return pos_sl

# %%
def bct_better():
    # boolean mask func. for BC direct thresholds with criterium <= 
    bct= read_BC_direct()
    bct.dropna(inplace = True)
    criterium = 15 # criterium BC direct threshold 15 dB or lower
    btr = bct <= criterium
    btr
    return btr

# %%
def bct_better2et3k():
    # function to combine criterium dB for BC direct thresholds at 2 & 3 k
    btr = bct_better()
    combi_23 = btr['BCdimp_3000'] #& btr['BCdimp_3000']
    combi_23.name = 'BCd_<=15_3k'
    return combi_23

# %%
def balanced_audible():
    # in the f-band is the fitting CROS-balanced & BC SL is >= threshold
    audible = diff_sl_filtered() & sl_bc_filtered()
    audible_hf = audible.iloc[:, 12 : 16]
    audible_hf
    # in all 1.6-4k bands at meantime is the fitting CROS-balanced & BC SL is >= threshold
    clmns = audible_hf.columns
    overall = audible_hf.loc[:, 'f_2000_Hz']
    for clmn in clmns:
        overall = overall & audible_hf.loc[:, clmn]
    overall.rename('balanced & audible', inplace=True)
    return overall

# %%
def mwu_test(df1,df2):
    # compare distribution with Mann Whitney U test

    mwu = dict()
    f = df1.columns.values.tolist()

    for i in range(len(f)):
        a = df1.iloc[:, i]
        b = df2.iloc[:, i]
        u_statistic, pVal = mannwhitneyu(a , b, use_continuity=False, alternative='two-sided') # scipy.stats mannwhitneyu test
        pVal = round(pVal, 3)
        st = {f[i]: [u_statistic, pVal]}
        mwu.update(st)

    u_test = pd.DataFrame.from_dict(mwu, dtype='float')
    diu =  {0: 'Mann-Whitney U statistic', 1: 'p-value (two-sided)'}
    u_test = u_test.rename(index=diu)
    return u_test

# %%
diff_sl_filtered()
# Out:
#           f_125_Hz  f_160_Hz  f_200_Hz  f_250_Hz  f_315_Hz  f_400_Hz  \
# Study_ID
# 34           False     False     False     False     False     False
# 35           False     False     False     False     False     False
# 43           False     False     False     False     False     False
# 47           False     False     False     False     False     False
# 50           False     False     False     False     False     False
# 53           False     False     False     False     False     False
# 54           False     False     False     False     False     False
# 56           False     False     False     False     False     False
# 59           False     False     False     False     False     False
# 66           False     False     False     False     False     False
# 71           False     False     False     False     False     False
# 72           False     False     False     False     False     False
# 73           False     False     False     False     False     False
# 74           False     False     False     False     False     False
# 75           False     False     False     False     False     False
# 76           False     False     False     False     False     False
# 77           False     False     False     False     False     False
# 80           False     False     False     False     False     False
# 81           False     False     False     False     False     False
# 83           False     False     False     False     False     False
#
#           f_500_Hz  f_630_Hz  f_800_Hz  f_1000_Hz  f_1250_Hz  f_1600_Hz  \
# Study_ID
# 34           False     False     False       True       True       True
# 35           False     False      True       True       True       True
# 43           False     False      True       True       True      False
# 47           False     False     False       True       True       True
# 50           False     False     False      False       True       True
# 53           False     False      True       True       True       True
# 54           False     False      True      False       True       True
# 56           False     False      True      False       True       True
# 59           False     False     False      False       True       True
# 66           False     False     False      False       True       True
# 71           False     False     False       True       True       True
# 72           False     False     False      False       True       True
# 73           False     False     False      False       True       True
# 74           False     False     False       True       True       True
# 75           False     False     False      False       True       True
# 76           False     False     False      False      False       True
# 77           False     False      True      False       True       True
# 80           False     False     False      False      False      False
# 81           False     False     False      False      False      False
# 83           False     False     False      False       True       True
#
#           f_2000_Hz  f_2500_Hz  f_3150_Hz  f_4000_Hz  f_5000_Hz  f_6300_Hz  \
# Study_ID
# 34             True       True       True       True       True       True
# 35            False       True       True       True       True       True
# 43            False      False       True      False       True       True
# 47             True       True       True       True       True       True
# 50             True      False       True       True       True       True
# 53             True      False       True      False       True       True
# 54             True       True       True       True       True       True
# 56             True       True       True       True       True       True
# 59             True       True       True       True       True       True
# 66             True       True       True       True       True       True
# 71             True       True       True       True       True       True
# 72             True      False       True       True       True       True
# 73             True       True       True       True       True       True
# 74             True       True       True      False       True       True
# 75             True       True       True       True       True       True
# 76             True       True       True       True       True       True
# 77             True       True       True       True       True       True
# 80             True       True       True       True       True       True
# 81            False       True       True       True       True       True
# 83             True       True       True       True       True       True
#
#           f_8000_Hz
# Study_ID
# 34             True
# 35             True
# 43             True
# 47            False
# 50             True
# 53            False
# 54             True
# 56             True
# 59            False
# 66             True
# 71             True
# 72             True
# 73             True
# 74             True
# 75             True
# 76            False
# 77            False
# 80            False
# 81             True
# 83             True

# %%
sl_bc_filtered()
# Out:
#           f_125_Hz  f_160_Hz  f_200_Hz  f_250_Hz  f_315_Hz  f_400_Hz  \
# Study_ID
# 34           False     False     False     False     False     False
# 35           False     False     False     False     False     False
# 43           False     False     False     False     False      True
# 47           False     False     False     False     False     False
# 50           False     False     False     False     False     False
# 53           False     False     False     False     False     False
# 54           False     False     False     False     False     False
# 56           False     False     False     False     False     False
# 59           False     False     False     False     False     False
# 66           False     False     False     False     False      True
# 71           False     False     False     False     False     False
# 72           False     False     False     False     False     False
# 73           False     False     False     False     False      True
# 74           False     False     False     False     False     False
# 75           False     False     False     False     False     False
# 76           False     False     False     False     False     False
# 77           False     False     False     False     False     False
# 80           False     False     False     False     False     False
# 81           False     False     False     False     False     False
# 83           False     False     False     False     False     False
#
#           f_500_Hz  f_630_Hz  f_800_Hz  f_1000_Hz  f_1250_Hz  f_1600_Hz  \
# Study_ID
# 34            True      True      True       True       True       True
# 35            True      True      True       True       True       True
# 43            True      True      True       True       True       True
# 47            True      True      True       True       True       True
# 50            True      True      True       True       True       True
# 53            True      True      True       True       True       True
# 54            True      True      True       True       True       True
# 56            True      True      True       True       True       True
# 59            True      True      True       True       True       True
# 66            True      True      True       True       True       True
# 71            True      True      True       True       True       True
# 72            True      True      True       True       True       True
# 73            True      True      True       True       True       True
# 74            True      True      True       True       True       True
# 75            True      True      True       True       True       True
# 76            True      True      True       True       True       True
# 77            True      True      True       True       True       True
# 80            True      True      True       True       True       True
# 81            True      True      True       True       True       True
# 83            True      True      True       True       True       True
#
#           f_2000_Hz  f_2500_Hz  f_3150_Hz  f_4000_Hz  f_5000_Hz  f_6300_Hz  \
# Study_ID
# 34             True       True       True       True      False      False
# 35             True       True       True       True      False      False
# 43             True       True       True      False       True       True
# 47             True       True       True       True       True       True
# 50             True       True       True       True       True       True
# 53             True       True       True       True       True       True
# 54             True       True       True       True       True       True
# 56             True       True       True      False       True       True
# 59             True       True       True       True       True       True
# 66             True       True       True       True       True       True
# 71             True       True       True       True      False      False
# 72             True       True       True       True       True       True
# 73             True       True       True       True       True       True
# 74             True       True       True       True       True       True
# 75             True       True       True       True       True       True
# 76             True       True       True       True       True       True
# 77             True       True       True       True       True       True
# 80             True       True       True       True       True       True
# 81             True       True       True       True       True       True
# 83             True       True       True       True       True       True
#
#           f_8000_Hz
# Study_ID
# 34            False
# 35            False
# 43             True
# 47             True
# 50             True
# 53             True
# 54             True
# 56             True
# 59             True
# 66            False
# 71            False
# 72             True
# 73             True
# 74             True
# 75            False
# 76             True
# 77            False
# 80             True
# 81             True
# 83             True

# %%
overall = pd.DataFrame(balanced_audible())
overall
# Out:
#           balanced & audible
# Study_ID
# 34                      True
# 35                     False
# 43                     False
# 47                      True
# 50                     False
# 53                     False
# 54                      True
# 56                     False
# 59                      True
# 66                      True
# 71                      True
# 72                     False
# 73                      True
# 74                     False
# 75                      True
# 76                      True
# 77                      True
# 80                      True
# 81                     False
# 83                      True

# %%
overall.value_counts()
# Out:
# balanced & audible
# True                  12
# False                  8
# dtype: int64

# %%
fltr_weak = overall['balanced & audible']==False
is_weak = overall[fltr_weak]
weak_cases = is_weak.index
weak_cases
# Out:
# Int64Index([35, 43, 50, 53, 56, 72, 74, 81], dtype='int64', name='Study_ID')

# %%
fltr_strong = overall['balanced & audible']==True
is_strong = overall[fltr_strong]
strong_cases = is_strong.index
strong_cases
# Out:
# Int64Index([34, 47, 54, 59, 66, 71, 73, 75, 76, 77, 80, 83], dtype='int64', name='Study_ID')

# %%
act = present_AC_thresholds()
act_weak = act.loc[weak_cases]
act_strong = act.loc[strong_cases]

# %%
act_weak
# Out:
#           AC_500  AC_1000  AC_2000  AC_4000  PTA (0.5-4 kHz)  PTA_HF (1-4 kHz)
# Study_ID
# 35            15       15       15       55             28.3              32.8
# 43            15       10        0       35             15.0              16.7
# 50             0        0        0       15              5.0               6.7
# 53            20       10       10       10             10.0              10.0
# 56            15       15       25       60             33.3              39.4
# 72             0        5       10       10              8.3               9.4
# 74            10       15       10        5             10.0               8.3
# 81             5       10       10       25             15.0              16.7

# %%
act_strong
# Out:
#           AC_500  AC_1000  AC_2000  AC_4000  PTA (0.5-4 kHz)  PTA_HF (1-4 kHz)
# Study_ID
# 34             5        5       10       40             18.3              22.8
# 47             5       10       15       15             13.3              14.4
# 54            15       10       15       35             20.0              23.3
# 59            10       15        5       20             13.3              12.8
# 66             5        0       10       25             11.7              15.6
# 71            20       15       15       20             16.7              17.2
# 73            10       10       20       20             16.7              18.9
# 75             5        5       30       30             21.7              27.2
# 76            10       10       10       15             11.7              12.2
# 77            20       10       15       15             13.3              14.4
# 80             5        0        5       25             10.0              13.3
# 83             5        5       15       15             11.7              13.9

# %%
mwu_test(act_weak,act_strong)
# Out:
#                           AC_500  AC_1000  AC_2000  AC_4000  PTA (0.5-4 kHz)  \
# Mann-Whitney U statistic  50.000   60.000   32.500   44.500           39.000
# p-value (two-sided)        0.873    0.332    0.215    0.785            0.485
#
#                           PTA_HF (1-4 kHz)
# Mann-Whitney U statistic             38.00
# p-value (two-sided)                   0.44

# %%
bct = read_BC_direct()
bct_weak = bct.loc[weak_cases]
bct_strong = bct.loc[strong_cases]
bct_strong
# Out:
#           BCdimp_250  BCdimp_500  BCdimp_750  BCdimp_1000  BCdimp_1500  \
# Study_ID
# 34                25          20          15           -5            5
# 47                25          15          25           10            5
# 54                25          20          15           20            5
# 59                33          25          30           25            5
# 66                20          10          10           10            0
# 71                25          25          25           10           10
# 73                15          15          15           15           15
# 75                25          25          20           10           15
# 76                33          30          30           25           10
# 77                25          30          15           20           20
# 80                30          20          25           25           10
# 83                25          15          15           20           -5
#
#           BCdimp_2000  BCdimp_3000  BCdimp_4000  BCdimp_6000
# Study_ID
# 34                 15           20           20           45
# 47                  5            5           10           10
# 54                 15           20           25           15
# 59                  5           15           20           15
# 66                 10           10           15           30
# 71                 20           15           25           45
# 73                 15           15           20           20
# 75                 15           15           10           35
# 76                 20           15            0           20
# 77                 15           20           20           30
# 80                 10           15           20           15
# 83                  0            0           15           10

# %%
bct_weak
# Out:
#           BCdimp_250  BCdimp_500  BCdimp_750  BCdimp_1000  BCdimp_1500  \
# Study_ID
# 35                18          20          15           15           10
# 43                15          15          15           10           10
# 50                25          20          15            5            5
# 53                25          25          15           10            0
# 56                25          30          15           30           20
# 72                25          15          15           20            5
# 74                25          25          20           15           15
# 81                33          30          15           15           35
#
#           BCdimp_2000  BCdimp_3000  BCdimp_4000  BCdimp_6000
# Study_ID
# 35                 35           15           30           50
# 43                 20           25           45           15
# 50                  5           15           20           15
# 53                 10           20           15           25
# 56                 25           35           50           10
# 72                 10           20           15           15
# 74                 10           20           15           25
# 81                 25           -5           10           25

# %%
mwu_test(bct_weak,bct_strong)
# Out:
#                           BCdimp_250  BCdimp_500  BCdimp_750  BCdimp_1000  \
# Mann-Whitney U statistic      40.000      55.000      31.000       43.000
# p-value (two-sided)            0.485       0.579       0.138        0.693
#
#                           BCdimp_1500  BCdimp_2000  BCdimp_3000  BCdimp_4000  \
# Mann-Whitney U statistic        58.00       61.000       67.500       57.500
# p-value (two-sided)              0.43        0.307        0.115        0.453
#
#                           BCdimp_6000
# Mann-Whitney U statistic       44.500
# p-value (two-sided)             0.783

# %%
sw = bct_strong.join(bct_weak, how='outer', lsuffix='_strong', rsuffix='_weak')

# %%
sw
# Out:
#           BCdimp_250_strong  BCdimp_500_strong  BCdimp_750_strong  \
# Study_ID
# 34                     25.0               20.0               15.0
# 35                      NaN                NaN                NaN
# 43                      NaN                NaN                NaN
# 47                     25.0               15.0               25.0
# 50                      NaN                NaN                NaN
# 53                      NaN                NaN                NaN
# 54                     25.0               20.0               15.0
# 56                      NaN                NaN                NaN
# 59                     33.0               25.0               30.0
# 66                     20.0               10.0               10.0
# 71                     25.0               25.0               25.0
# 72                      NaN                NaN                NaN
# 73                     15.0               15.0               15.0
# 74                      NaN                NaN                NaN
# 75                     25.0               25.0               20.0
# 76                     33.0               30.0               30.0
# 77                     25.0               30.0               15.0
# 80                     30.0               20.0               25.0
# 81                      NaN                NaN                NaN
# 83                     25.0               15.0               15.0
#
#           BCdimp_1000_strong  BCdimp_1500_strong  BCdimp_2000_strong  \
# Study_ID
# 34                      -5.0                 5.0                15.0
# 35                       NaN                 NaN                 NaN
# 43                       NaN                 NaN                 NaN
# 47                      10.0                 5.0                 5.0
# 50                       NaN                 NaN                 NaN
# 53                       NaN                 NaN                 NaN
# 54                      20.0                 5.0                15.0
# 56                       NaN                 NaN                 NaN
# 59                      25.0                 5.0                 5.0
# 66                      10.0                 0.0                10.0
# 71                      10.0                10.0                20.0
# 72                       NaN                 NaN                 NaN
# 73                      15.0                15.0                15.0
# 74                       NaN                 NaN                 NaN
# 75                      10.0                15.0                15.0
# 76                      25.0                10.0                20.0
# 77                      20.0                20.0                15.0
# 80                      25.0                10.0                10.0
# 81                       NaN                 NaN                 NaN
# 83                      20.0                -5.0                 0.0
#
#           BCdimp_3000_strong  BCdimp_4000_strong  BCdimp_6000_strong  \
# Study_ID
# 34                      20.0                20.0                45.0
# 35                       NaN                 NaN                 NaN
# 43                       NaN                 NaN                 NaN
# 47                       5.0                10.0                10.0
# 50                       NaN                 NaN                 NaN
# 53                       NaN                 NaN                 NaN
# 54                      20.0                25.0                15.0
# 56                       NaN                 NaN                 NaN
# 59                      15.0                20.0                15.0
# 66                      10.0                15.0                30.0
# 71                      15.0                25.0                45.0
# 72                       NaN                 NaN                 NaN
# 73                      15.0                20.0                20.0
# 74                       NaN                 NaN                 NaN
# 75                      15.0                10.0                35.0
# 76                      15.0                 0.0                20.0
# 77                      20.0                20.0                30.0
# 80                      15.0                20.0                15.0
# 81                       NaN                 NaN                 NaN
# 83                       0.0                15.0                10.0
#
#           BCdimp_250_weak  BCdimp_500_weak  BCdimp_750_weak  BCdimp_1000_weak  \
# Study_ID
# 34                    NaN              NaN              NaN               NaN
# 35                   18.0             20.0             15.0              15.0
# 43                   15.0             15.0             15.0              10.0
# 47                    NaN              NaN              NaN               NaN
# 50                   25.0             20.0             15.0               5.0
# 53                   25.0             25.0             15.0              10.0
# 54                    NaN              NaN              NaN               NaN
# 56                   25.0             30.0             15.0              30.0
# 59                    NaN              NaN              NaN               NaN
# 66                    NaN              NaN              NaN               NaN
# 71                    NaN              NaN              NaN               NaN
# 72                   25.0             15.0             15.0              20.0
# 73                    NaN              NaN              NaN               NaN
# 74                   25.0             25.0             20.0              15.0
# 75                    NaN              NaN              NaN               NaN
# 76                    NaN              NaN              NaN               NaN
# 77                    NaN              NaN              NaN               NaN
# 80                    NaN              NaN              NaN               NaN
# 81                   33.0             30.0             15.0              15.0
# 83                    NaN              NaN              NaN               NaN
#
#           BCdimp_1500_weak  BCdimp_2000_weak  BCdimp_3000_weak  \
# Study_ID
# 34                     NaN               NaN               NaN
# 35                    10.0              35.0              15.0
# 43                    10.0              20.0              25.0
# 47                     NaN               NaN               NaN
# 50                     5.0               5.0              15.0
# 53                     0.0              10.0              20.0
# 54                     NaN               NaN               NaN
# 56                    20.0              25.0              35.0
# 59                     NaN               NaN               NaN
# 66                     NaN               NaN               NaN
# 71                     NaN               NaN               NaN
# 72                     5.0              10.0              20.0
# 73                     NaN               NaN               NaN
# 74                    15.0              10.0              20.0
# 75                     NaN               NaN               NaN
# 76                     NaN               NaN               NaN
# 77                     NaN               NaN               NaN
# 80                     NaN               NaN               NaN
# 81                    35.0              25.0              -5.0
# 83                     NaN               NaN               NaN
#
#           BCdimp_4000_weak  BCdimp_6000_weak
# Study_ID
# 34                     NaN               NaN
# 35                    30.0              50.0
# 43                    45.0              15.0
# 47                     NaN               NaN
# 50                    20.0              15.0
# 53                    15.0              25.0
# 54                     NaN               NaN
# 56                    50.0              10.0
# 59                     NaN               NaN
# 66                     NaN               NaN
# 71                     NaN               NaN
# 72                    15.0              15.0
# 73                     NaN               NaN
# 74                    15.0              25.0
# 75                     NaN               NaN
# 76                     NaN               NaN
# 77                     NaN               NaN
# 80                     NaN               NaN
# 81                    10.0              25.0
# 83                     NaN               NaN

# %%
sw1k = sw[['BCdimp_1000_strong', 'BCdimp_1000_weak']]

# make a figure to plot BC direct threshold at 1 kHz for strong & weak fitting groups
ttl = 'Qualitative analysis of fittings as function of BC direct at 1k'

tp = pd.melt(sw1k, var_name = 'strong & weak fitting groups', value_name = 'BC direct threshold at 1 kHz [dB HL]') 

fig, ax = plt.subplots(constrained_layout=True)

fig.set_figheight(5)
fig.set_figwidth(5)

ax = sns.swarmplot(data = tp, x = 'strong & weak fitting groups', y = 'BC direct threshold at 1 kHz [dB HL]', 
                   size=6, hue = 'strong & weak fitting groups')

ax.set_title(ttl)
plt.legend(bbox_to_anchor=(1, 0.15), fontsize='large')

plt.show()

# %%
sw2k = sw[['BCdimp_2000_strong', 'BCdimp_2000_weak']]

# make a figure to plot BC direct threshold at 3 kHz for strong & weak fitting groups
ttl = 'Qualitative analysis of fittings as function of BC direct at 2k'

tp = pd.melt(sw2k, var_name = 'strong & weak fitting groups', value_name = 'BC direct threshold at 2 kHz [dB HL]') 

fig, ax = plt.subplots(constrained_layout=True)

fig.set_figheight(5)
fig.set_figwidth(5)

ax = sns.swarmplot(data = tp, x = 'strong & weak fitting groups', y = 'BC direct threshold at 2 kHz [dB HL]', 
                   size=6, hue = 'strong & weak fitting groups')

ax.set_title(ttl)
#plt.legend(bbox_to_anchor=(0.15, 0.25), fontsize='large')

plt.show()

# %%
sw3k = sw[['BCdimp_3000_strong', 'BCdimp_3000_weak']]

# make a figure to plot BC direct threshold at 3 kHz for strong & weak fitting groups
ttl = 'Qualitative analysis of fittings as function of BC direct at 3k'

tp = pd.melt(sw3k, var_name = 'strong & weak fitting groups', value_name = 'BC direct threshold at 3 kHz [dB HL]') 

fig, ax = plt.subplots(constrained_layout=True)

fig.set_figheight(5)
fig.set_figwidth(5)

ax = sns.swarmplot(data = tp, x = 'strong & weak fitting groups', y = 'BC direct threshold at 3 kHz [dB HL]', 
                   size=6, hue = 'strong & weak fitting groups')

ax.set_title(ttl)
#plt.legend(bbox_to_anchor=(0.15, 0.25), fontsize='large')

# save figure to file

plt.show()

# %%
sw4k = sw[['BCdimp_4000_strong', 'BCdimp_4000_weak']]

# make a figure to plot BC direct threshold at 3 kHz for strong & weak fitting groups
ttl = 'Qualitative analysis of fittings as function of BC direct at 4k'

tp = pd.melt(sw4k, var_name = 'strong & weak fitting groups', value_name = 'BC direct threshold at 4 kHz [dB HL]') 

fig, ax = plt.subplots(constrained_layout=True)

fig.set_figheight(5)
fig.set_figwidth(7)

ax = sns.swarmplot(data = tp, x = 'strong & weak fitting groups', y = 'BC direct threshold at 4 kHz [dB HL]', 
                   size=6, hue = 'strong & weak fitting groups')

ax.set_title(ttl)
#plt.legend(bbox_to_anchor=(0.15, 0.25), fontsize='large')

plt.show()

# %%
bcb = bct_better2et3k()
bcb
# Out:
# Study_ID
# 34    False
# 35     True
# 43    False
# 47     True
# 50     True
# 53    False
# 54    False
# 56    False
# 59     True
# 66     True
# 71     True
# 72    False
# 73     True
# 74    False
# 75     True
# 76     True
# 77    False
# 80     True
# 81     True
# 83     True
# Name: BCd_<=15_3k, dtype: bool

# %%
bcb = pd.DataFrame(bcb)
qlt = overall.join(bcb, how='outer')
qlt
# Out:
#           balanced & audible  BCd_<=15_3k
# Study_ID
# 34                      True        False
# 35                     False         True
# 43                     False        False
# 47                      True         True
# 50                     False         True
# 53                     False        False
# 54                      True        False
# 56                     False        False
# 59                      True         True
# 66                      True         True
# 71                      True         True
# 72                     False        False
# 73                      True         True
# 74                     False        False
# 75                      True         True
# 76                      True         True
# 77                      True        False
# 80                      True         True
# 81                     False         True
# 83                      True         True

# %%
# number of subjects with balanced en audible SL BC
qlt['balanced & audible'].sum()
# Out:
# 12

# %%
# number of subjects fulfilling criterium BCdT 2 & 3 k
qlt['BCd_<=15_3k'].sum()
# Out:
# 12

# %%
# number of subjects with balanced en audible SL BC fulfilling criterium BCdT 2 & 3 k
vrf = qlt['balanced & audible'] & qlt['BCd_<=15_3k']
vrf.sum()
# Out:
# 9

# %%
# number of subjects with balanced en audible SL BC not fulfilling criterium BCdT 2 & 3 k
vrf2 = qlt['balanced & audible'] & ~qlt['BCd_<=15_3k']
vrf2.sum()
# Out:
# 3

# %%
# number of subjects with NOT balanced en audible SL BC fulfilling criterium BCdT 2 & 3 k
vrf3 = ~qlt['balanced & audible'] & qlt['BCd_<=15_3k']
vrf3.sum()
# Out:
# 3

# %%
# sensitivity
round(vrf.sum() / qlt['balanced & audible'].sum(),2)
# Out:
# 0.75

# %%
# specificity %
negatieve = len(qlt) - qlt['balanced & audible'].sum()
thrue_neg = negatieve - vrf3.sum()
round(thrue_neg / negatieve, 2)
# Out:
# 0.62

# %%
# "best" criterium BC-direct <= 15 dB at 3 kHz
